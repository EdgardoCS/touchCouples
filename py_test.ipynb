# %%
import pandas as pd
import os

# 1. Let's see exactly where Python thinks it is running from
print("Current Working Directory:", os.getcwd())

# 2. Try to load the simplest dataframe possible
try:
    df = pd.read_csv('source/FReDA4.csv')
    print("\n✅ SUCCESS! Dataframe loaded into memory.")
    print(f"Total Rows and Columns: {df.shape}")
    print("\n--- First 5 Rows ---")
    print(df.head())

except Exception as e:
    print("\n❌ CRASHED! Python cannot load the CSV. Here is the exact error:")
    print(e)
# Out:
# Current Working Directory: C:\Users\Edo\Documents\GitHub\touchCouples
#
# ✅ SUCCESS! Dataframe loaded into memory.
# Total Rows and Columns: (13600, 50)
#
# --- First 5 Rows ---
#    CoupleId    Role  Age  Work Status  Sex  Relationship Satisfaction  \
# 0         1  Anchor   39          1.0  1.0                       10.0
# 1         2  Anchor   39          2.0  0.0                        6.0
# 2         3  Anchor   42          1.0  1.0                       10.0
# 3         4  Anchor   40          2.0  0.0                        6.0
# 4         5  Anchor   50          NaN  1.0                        8.0
#
#    Communication Quality  Kiss Frequency  Hold Frequency  Hug Frequency  ...  \
# 0                   23.0               2               3              3  ...
# 1                   17.0               1               1              1  ...
# 2                   26.0               0               1              1  ...
# ...
